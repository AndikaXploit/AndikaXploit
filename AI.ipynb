# %% [markdown]
# <a href="https://colab.research.google.com/github/AndikaXploit/AndikaXploit/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [0,10]
y = [100,250]

plt.plot(x,y, linestyle = 'dotted')
plt.xlabel("Baris X")
plt.ylabel("Baris Y")
plt.title("study date SIRCLE") #judul
plt.show()

# %%
import numpy as np
y = np.array([3,7,2,8])
plt.plot(5)
plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
x = np.array([5,6,3,7,1])
y = np.array([22,34,23,12,20])

plt.scatter(x,y, color = "red")
plt.show()

# %% [markdown]
# BAR

# %%
x = np.array(["A","B","C","D"])
y = np.array([3,6,2,4])

plt.bar(x,y, width = 0.5)
plt.show()

# %% [markdown]
# PIE CHAR

# %%
Y = np.array([3,5,8,1])
x = np.array(["jeruk","anggur","apel","semangka"])

plt.pie(y, labels = x)
plt.show()
